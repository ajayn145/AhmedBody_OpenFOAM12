# %%
# DAY 1 → Problem Definition & Simulation Strategy

# %%
#1. Objective

#Simualte external aerodynamics of a 25deg Ahmed body using steady RANS in Openfoam.
#Primary targets:
#- compute drag coefficents (Cd)
#-Study wake structure
#-Validate against literature Cd ~ 0.29 to 0.30

# %%
# 2. Geometry Definition

#Main dimensions:
#- Length (L) = 1.044m
#- Height (H) = 0288m
#- Width (W) = 0389m
#- Slant length (Ls) = 0.222m
#- Slant angle (theta) = 25deg

# %%
#3.Flow Conditions

#Assumptions:
#- Incompressible air
#- ρ = 1.225 kg/m³
#- μ = 1.789e−5 Pa·s
#- Freestream velocity U = 40 m/s
#Reynolds number estimate:

#        Re = (ρ U L) / μ

#Target Re ≈ O(10⁶), ensuring fully turbulent regime.

# %%
## 4. Solver Selection

#Solver: simpleFoam

#Reason:
#- Steady-state RANS solver
#- Suitable for high Reynolds external flows
#- Computationally efficient compared to transient LES/DES

# %%
## 5. Turbulence Model

#Model: kOmegaSST

#Reason:
#- Accurate near-wall prediction
#- Better separation handling than k-epsilon
#- Industry standard for automotive aerodynamics

# %%
## 6. Modeling Strategy

#- Steady RANS approach
#- Moving ground boundary condition
#- Symmetry not used (full 3D domain)
#- Geometry created parametrically in Gmsh
#- Mesh will be generated in Gmsh (not snappyHexMesh)

# %%
## 7. Expected Physical Behavior

#For 25° Ahmed body:
#- Separation occurs at rear slant
#- Moderate recirculation bubble
#- Expected Cd ≈ 0.29–0.30

# %%
import math

rho = 1.225
U = 40
L = 1.044
mu = 1.789e-5

Re = rho * U * L / mu
Re

# %%
# Day 2 – Geometry Construction & Debugging (Gmsh + OpenCASCADE)

# %%
##1. Objective

#Create a clean, parametric 3D Ahmed body geometry (25deg slant) using gmsh with OpenCASCADE kernel.

# %%
## 2. Geometry Strategy

#Approach:
#- Use OpenCASCADE kernel for solid modeling
#- Construct base rectangular block
#- Construct rear slanted wedge
#- Use Boolean operations to obtain single solid volume

# L = 1.044
#- H = 0.288
#- W = 0.389
#- Ls = 0.222
#- θ = 25°

#Slant height derived from:

#H_slant = Ls * tan(θ)

# %%
## 3. Boolean Operation Strategy

#Initial attempt:
#- BooleanDifference used to carve slant from base block

#Issue observed:
#- Internal partitions created
#- Multiple volumes appeared
#- Tag conflicts generated OpenCASCADE errors

#Error example:
#- "OpenCASCADE point with tag already exists"
#- Curve loop duplication
#- Surface tag conflicts

#Root cause:
#- Reuse of low-number entity tags
#- Multiple geometry redefinitions in same script
#- Incorrect Boolean volume referencing

# %%
## 4. Final Correct Approach

Solution implemented:
- Explicit parametric definition
- Controlled entity numbering
- Used BooleanUnion to fuse geometry
- Ensured single continuous volume
- Verified geometry via rotation and visibility check

Result:
- Clean slanted rear face
- Single solid volume
- No parser errors
- Geometry validated visually

# %%
#Lesson learned

1. OpenCASCADE requires strict tag control.
2. BooleanDifference may create partitions if not handled carefully.
3. Parametric geometry improves reproducibility.
4. Always verify final volume count before meshing.

# %%
import math

Ls = 0.222
theta = math.radians(25)
Hslant = Ls * math.tan(theta)

Hslant

# %%
## Final Geometry Visualization

![Ahmed Body Geometry](../figures/ahmed25_geometry.png)

# %%
# Day 3 – Mesh Generation, OpenFOAM Conversion & Validation

# %%
## 1. Objective

Generate a CFD-ready 3D mesh for the Ahmed body wind tunnel domain, 
convert it to OpenFOAM format, and validate mesh quality using checkMesh.

# %%
## 2. Meshing Strategy

### Mesh Type
- Unstructured tetrahedral mesh
- 100% tetra elements

### Global Mesh Control
- Mesh.CharacteristicLengthMin = 0.05
- Mesh.CharacteristicLengthMax = 0.2

Purpose:
- Coarse mesh in far-field
- Controlled overall cell count

# %%
## 3. Local Refinement Strategy

Distance-based refinement field applied on body surfaces:

- SizeMin = 0.02
- SizeMax = 0.2
- DistMin = 0.05
- DistMax = 0.5

Purpose:
- Fine mesh near Ahmed body
- Gradual transition outward
- Resolve boundary layer region and wake origin

# %%
## 4. Mesh Statistics (Before Conversion)

- Points: 8,260
- Cells: 40,316
- Element Type: Tetrahedra only
- Single fluid volume

This mesh is suitable for:
- Workflow validation
- Initial steady RANS simulation
- Not yet suitable for high-fidelity drag prediction

# %%
## 5. Physical Groups (Patch Mapping)

### Volume
- fluid

### Surfaces
- inlet
- outlet
- top
- bottom
- side1
- side2
- body

These physical groups are required for proper OpenFOAM patch generation.

# %%
## 6. Mesh Export & Conversion

Mesh exported as:
- Gmsh MSH Version 2 ASCII

Conversion tool:
- gmshToFoam

Important workflow rule:
- gmshToFoam must be executed from case root directory.

# %%
## 7. checkMesh Validation

Results summary:

- Regions: 1 (Correct)
- Max aspect ratio: 7.80 (OK)
- Max skewness: 0.89 (OK)
- Max non-orthogonality: 65.1° (Acceptable for RANS)
- No negative volumes
- No topology errors

Verdict:
Mesh OK – Solver Ready

# %%
## 8. Lessons Learned

1. OpenFOAM utilities require correct directory structure.
2. MSH must be exported as Version 2 ASCII.
3. Physical groups in Gmsh directly define OpenFOAM patches.
4. Boolean operations must be validated before meshing.
5. checkMesh is mandatory before solving.
6. Clipping plane is useful for internal mesh inspection.

# %%
## 9. Engineering Reflection

The mesh is intentionally moderate in size (~40k cells) 
to validate solver pipeline before increasing resolution.

Next step:
- Define boundary conditions
- Configure turbulence model
- Run simpleFoam

# %%
## Final Mesh Visualization

![Ahmed Body Geometry](../figures/ahmed25_mesh_1.png)

# %%
![Ahmed Body Geometry](../figures/ahmed25_mesh_2.png)

# %%
#mesh quality metrics

Mesh stats
    points:           8260
    faces:            84072
    internal faces:   77192
    cells:            40316
    faces per cell:   4
    boundary patches: 7
    point zones:      0
    face zones:       0
    cell zones:       1

# %%
# Day 4 – Setting up of the OPENFOAM solver

Copied the "pitzdaily" exaample from Openfoam incompressibleFluid Folder.

pitzDaily is a 3D turbulent incompressible flow case over a backward-facing step.
It is used to:
- Study flow separation
- Study reattachment length
- Test turbulence models
- Validate numerical schemes

It is simple, but it contains:
- Boundary layer separation
- Recirculation zone
- Turbulent mixing

# %%
## Why I Copied pitzDaily

Instead of starting from scratch, I used pitzDaily as a template because it already contains:

- Correct fvSchemes structure
- Correct fvSolution setup
- Working turbulence model configuration
- Proper solver compatibility with incompressibleFluid

It is like using a working engine and modifying the car body.

# %%
### Key Understanding

pitzDaily is not related to Ahmed body geometry.

It is just a stable OpenFOAM starting template for turbulent incompressible simulations.

It saved time in setting up:
- Numerical schemes
- Solver dictionaries
- Turbulence configuration

# %%
### What I Changed From pitzDaily

- Replaced geometry with Ahmed body
- Modified mesh
- Updated boundary conditions
- Adjusted solver settings
- Added forces function

# %%
## Understanding Backward-Facing Step Physics (pitzDaily Physics)

### Simple Explanation

Imagine water flowing smoothly inside a straight pipe.

Now suddenly, the pipe floor drops down like a small cliff.

What happens?

The water cannot instantly follow the sharp drop.

So it:

- Detaches from the wall
- Leaves an empty swirling region behind the step
- Forms a recirculation bubble
- Eventually reattaches further downstream

That is backward-facing step flow.

---

### What Physically Happens?

When fluid hits the step:

1. Boundary layer separates
2. A low-pressure region forms behind the step
3. A recirculation zone appears
4. Flow reattaches downstream
5. Turbulence increases in shear layer

---

### Key Physical Concepts

#### 1. Flow Separation
The boundary layer loses momentum and detaches from the wall.

#### 2. Recirculation Zone
A region where flow actually reverses direction.

Velocity inside this region becomes negative locally.

#### 3. Reattachment Length
Distance from the step to where the flow sticks back to the wall.

This length is very important for validating turbulence models.

---

### Why Is This Case Popular?

Because it contains:

- Adverse pressure gradient
- Flow separation
- Turbulent shear layer
- Reattachment physics

But geometry is simple.

So it is perfect for testing:
- Turbulence models
- Numerical schemes
- Solver stability

---

### Connection to Ahmed Body

Ahmed body also has:

- Flow separation
- Large recirculation zone behind the slant
- Wake turbulence

So pitzDaily is a simpler cousin of the Ahmed wake problem.

Backward-facing step = 2D separation case  
Ahmed body = 3D separation + wake case


Also, Backward-facing step is often used to check if your turbulence model predicts:

                            1. Correct reattachment length
                            
                            2. Correct wall shear stress
                            
                            3. Correct pressure recovery

If it fails there, it will fail in complex geometry.

# %%
#Major Issues encountered whie setting up the case →
1. Keyword 'PIMPLE' is undefined
2. Missing OmegaFinal Entry
3. wallDist undefined
4. div(phi,omega) missing
5. Courant number explosion
6. no forces.dat generated
7. projected frontal area error for Cd calculation.

# %% [markdown]
# ##Now Lets go into the Issues →
#
# ## Issue 1 – Keyword "PIMPLE" Undefined
# ### Understanding This at Solver Architecture Level
#
# When I got the error:
#
#     keyword PIMPLE is undefined
#
# it was not just a syntax mistake.
# It was a solver–algorithm mismatch.
#
# ---
#
# ## 1️⃣ How OpenFOAM Actually Works Internally
#
# OpenFOAM solvers are C++ programs.
#
# Each solver is written with a specific pressure–velocity coupling algorithm.
#
# For incompressible flows, there are three main algorithms:
#
# - SIMPLE  → steady-state
# - PISO    → transient
# - PIMPLE  → hybrid (PISO + SIMPLE)
#
# The solver expects a specific dictionary block inside `fvSolution`.
#
# If the solver code contains something like:
#
#     const dictionary& pimple = mesh.solutionDict().subDict("PIMPLE");
#
# then OpenFOAM *must* find a block named:
#
#     PIMPLE
#     {
#         ...
#     }
#
# If it does not exist → fatal error.
#
# That is exactly what happened.
#
# ---
#
# ## 2️⃣ What Was My Mistake?
#
# I copied a case template that had:
#
#     SIMPLE
#     {
#         ...
#     }
#
# But my solver was:
#
#     incompressibleFluid
#
# And `incompressibleFluid` is written using PIMPLE.
#
# So internally the solver tried to read:
#
#     solutionDict().subDict("PIMPLE")
#
# But found no such block.
#
# Hence:
#
#     keyword PIMPLE is undefined
#
# ---
#
# ## 3️⃣ Why Does incompressibleFluid Use PIMPLE?
#
# Because it is designed to handle:
#
# - Transient simulations
# - Adjustable time stepping
# - Outer pressure–velocity corrections
# - More stability for larger time steps
#
# PIMPLE combines:
#
# PISO (good for transient accuracy)
# +
# SIMPLE (good for iterative pressure correction)
#
# So it is more robust than pure PISO.
#
# ---
#
# ## 4️⃣ What Is Inside the PIMPLE Block?
#
# Example:
#
#     PIMPLE
#     {
#         nOuterCorrectors 2;
#         nCorrectors 2;
#         nNonOrthogonalCorrectors 0;
#     }
#
# Meaning:
#
# nOuterCorrectors:
#     How many times we repeat the full pressure–momentum loop per time step.
#
# nCorrectors:
#     How many pressure corrections inside each outer loop.
#
# nNonOrthogonalCorrectors:
#     Extra corrections for skewed meshes.
#
# ---
#
# ## 5️⃣ What Happens Each Time Step Internally?
#
# At each time step:
#
# 1. Solve momentum equation (U)
# 2. Predict pressure
# 3. Correct pressure
# 4. Correct velocity
# 5. Update turbulence equations (k, omega)
# 6. Repeat if outer correctors > 1
#
# Then move to next time step.
#
# If PIMPLE block is missing → solver cannot perform this loop.
#
# ---
#
# ## 6️⃣ What I Learned
#
# - OpenFOAM dictionaries are directly tied to solver C++ code.
# - Errors are often architecture-level, not syntax-level.
# - Solver type determines required dictionary structure.
# - You cannot mix SIMPLE with a PIMPLE-based solver.
#
# This was my first real exposure to solver-level understanding.
#
#
# Why Is PIMPLE More Stable Than Pure PISO?
# Think about what is happening in your Ahmed case:
# 3D geometry, Strong separation, Large wake, Turbulence model (kOmegaSST), Adjustable time step
# This is not a simple laminar channel flow.
#
# 1️⃣ What Pure PISO Does
# PISO (Pressure Implicit Splitting Operator) is designed for Transient simulations, Small time steps, High temporal accuracy.
# At each time step it does Solve momentum, Correct pressure, Correct velocity, Move to next time step
# Usually only 1 outer loop.
#
# Important:
#
# PISO assumes the time step is small enough that the solution does not drift far from correct.
#
# If time step is large → instability.
#
# 2️⃣ What SIMPLE Does?
# SIMPLE is designed for Steady-state simulations,  Iterative convergence at a fixed time level
#
# It does Repeat pressure–velocity correction, until convergence at same time step.
# It is more stable for steady cases, but not naturally transient-accurate.
#
# 3️⃣ What PIMPLE Does?
#
# PIMPLE = PISO + SIMPLE
#
# It allows Multiple outer corrections per time step, Iterative correction inside each time step, Larger time steps than pure PISO, Better stability in complex turbulent flows
#
# In other words Instead of trusting one correction per time step, PIMPLE says:
#
# “Let me correct pressure and velocity several times before moving forward.”
#
# That reduces divergence.
#
# Why This Matters For Ahmed Body?
#
# Ahmed body has Large separation bubble, Strong adverse pressure gradient, Vortex shedding tendencies, Coupled turbulence equations, Pressure–velocity coupling is strong.
# If you only correct once (PISO), errors accumulate quickly. But With PIMPLE, You re-correct momentum, Re-correct pressure, Stabilize turbulence update, Reduce residual oscillation
# That prevents Courant explosion.
#
# Simple Analogy →
# PISO: Walk forward and adjust direction once.
# PIMPLE: Walk forward, check direction, adjust, check again, adjust again, then move
#
#
# Why SIMPLE (Steady-State) Is Not Ideal for Ahmed Wake?
# Ahmed body wake is not steady in reality.
#
# 1️⃣ What SIMPLE Assumes
#
# SIMPLE is a steady-state algorithm.
#
# It assumes
#     $$
# \frac{\partial}{\partial t} = 0
# $$
#
# Meaning: Flow does not change with time.
# It tries to find one single solution that satisfies Momentum equation, Continuity equation, Turbulence equations. All at once.
#
# 2️⃣ Why That Is a Problem for Ahmed Body
# Ahmed wake has Large 3D recirculation, Shear layer instability, Possible vortex shedding, Turbulent fluctuations, These are inherently unsteady phenomena.
# If you force the solver to find a steady solution, It will try to “average out” the wake artificially. That leads to Artificially damped wake Incorrect separation length, Wrong pressure recovery, Incorrect drag
#
#
# 3️⃣ What Happens in Practice If you run SIMPLE for Ahmed body?
#
# It may converge numerically, Residuals may go downn. But the wake physics may be suppressed. You get a smooth but wrong answer.
#
# 4️⃣ Why Transient PIMPLE Is Better
#
# Transient simulation allows:
#
# $$
# \frac{\partial}{\partial t} != 0
# $$
#
# Meaning:    Flow is allowed to evolve naturally.
#             Wake oscillations form.
#             Recirculation adjusts.
#             Pressure field stabilizes dynamically.
#
# Then you get the Time-average the drag force which gives physically meaningful Cd.
#
# Did I Perform a Truly Unsteady Study?
# No. Even though we used a transient solver, we are still doing URANS (Unsteady RANS) not LES, not DNS. Because I used kOmegaSST, which is a RANS turbulence model. RANS models are Time-average the Navier–Stokes equations, Model turbulent fluctuations. They Do not resolve real vortex shedding structures. Even if you run them transiently, they still Model turbulence, statistically. They do not resolve instantaneous turbulence.
#
# What You Actually Did?
# I solved Unsteady RANS (URANS), wherein, Large-scale unsteadiness may appear, but turbulence is still modeled. The Small-scale structures are averaged. So the wake is not fully physical. It is a modeled wake.
#
# What Would Be a True Unsteady Study?
# To truly capture wake physics, you would need LES (Large Eddy Simulation) or DES (Detached Eddy Simulation), Very fine mesh in wake, Small time steps, Long sampling window. Then you would see Periodic vortex shedding, Strouhal number, Wake oscillation frequency. You did not compute Strouhal number, Lift oscillation frequency, Spectral analysis. So it was not a full unsteady aerodynamic study.
#
# Why URANS Is Acceptable in Automotive Industry for Drag Prediction?
# URANS is widely used in automotive industry because design engineers are interested in mean drag coefficient, not instantaneous turbulence structures.
# LES provides higher fidelity but at very high computational cost. URANS provides a reasonable balance between accuracy and cost, making it suitable for iterative vehicle design studies.
#
# I used Transient solver (PIMPLE) and RANS turbulence model (kOmegaSST). RANS already time-averages turbulence mathematically. So the question is, If turbulence is already averaged in RANS, why do we still need to run the simulation for several seconds and time-average drag? Why not just run 0.1 s and compute Cd immediately?
# Ans:
# There are 2 types of unsteadiness in CFD→
# 1. Small-scale turbulence, which are Tiny chaotic eddies, Very high frequency and Modeled by RANS. You do not resolve these.
# 2. Large-scale flow structures, wherein Wake growth, Separation bubble formation, Recirculation stabilization, Pressure field evolution. These are NOT automatically averaged by RANS. They must physically develop in time.
#                 In Your Ahmed Case, When you start at time = 0, Flow is artificial, Wake does not exist yet, Pressure field is wrong, Separation has not formed fully. It takes time for Boundary layer to separate, Recirculation zone to grow, Wake to stabilize. Drag to settle. Even though turbulence is modeled, the flow field still evolves. That’s Why 0.1sec Was Meaningless. At 0.1sec, Wake not fully formed, Drag not stabilized, Pressure field still adjusting.  But At 5secs Flow-through time repeated many times Wake stabilized, Drag approaching quasi-steady mean.

# %% [markdown]
# ## Issue 2: Missing OmegaFinal Entry
#
# OpenFOAM sometimes solves turbulence equations twice per time step:
# First-time solving: rough solve
# Final solving: more strict solve
# If you don’t tell it how to do the second solve → it throws error.
#
# Since I am using k-omega SST model. It solves two transport equations→
# 1. k → turbulence kinetic energy
# 2. omega → specific dissipation rate
#
# These equations are stiff and strongly coupled with velocity field, wall gradients, separation zone.
# The near separation and recirculation in ahmed body makes the omega highly sensitive. If not solved
# accurately, wall shear prediction will be wrong, separation point shifts, drag becomes garbage.
#
# The solver architecture is as follows ☻6
# At each time step , PIMPLE does fix velocity, fix pressure, fix turbulence and repeat a few
# times. These repeats are called outer correctors in solver.
# Imagine time step = 1sec. Inside that 1sec, solver loops 3 times →
# Loop 1 → rough solve
# Loop 2 → better solve
# Loop 3→ final careful solve
# In the last loop 3, solver wants stricter convergence. For that it looks for UFinal, pFinal
# omegaFinal and kFinal.
# And this time I didn't gave omegaFinal
#
# Why it is needed? Because turbulence equation strongly influence the pressure correction loop.
# Omega conrols dissipation, affects wall shear, affects separation and affects drag. If omegaFinal
# is not accurate, then Cd will be wrong, wake may shift and instability may grow.
#
# Why do you think turbulence equations are more sensitive than velocity equations in external aerodynamics?
# Velocity equation is governed by Inertia, pressure and viscosity. These are strong, stable physical forces.
# But turbulence equations depend on velocity gradients, depend on wall distance, non-linear production
# and destruction terms and also can blow up if not balanced.
# So      $$
#         \frac{\partial}{\partial t} = Production - Destruction
#         $$
#
# If procuction slightly too large → omega explodes
# If destruction is too large → turbulence dies
#
# Small error → big consequences.

# %% [markdown]
# ## Issue 3: wallDist Undefined
#
# ### Error:
# Solver could not find wall distance definition
#
# ### Error:
# Solver could not find wall distance definition.
#
# ### Root Cause:
# k-omega SST turbulence model requires distance-to-wall field (y)
# for near-wall dissipation and blending functions.
#
# ### Physics Insight:
# Near-wall turbulence depends strongly on distance to wall.
# Omega equation contains terms proportional to 1/y².
#
# Without wall distance:
# - Turbulence cannot be computed
# - Separation prediction becomes invalid
#
# Without wall distance:
# - Turbulence cannot be computed
# - Separation prediction becomes invalid
#
#
# wallDist means → distance from each cell to the nearest wall
#
# why it is needed?
# Velocity near the wall is 0 (no slip condition). Here there will be very large velocity gradient,
# very high shear, very strong turbulence production. So when using the k-omega SST model, omega-equation contains terms like $$
#                              \frac{1}{y^2}
#                              $$
# where y → distance to wall.
# Also Near-wall formulation switched behaviour based on distance to wall and boundary layer thickness. In kOmega SST, k-omega blends near the wall and k-epsilon blends away from wall. So, in short without the wall distance, model does not know when to switch behaviour. Therefore, the solver crashes.
# In solver, the command "wallDist y(mesh);" cretaes a field storing distance from every
# cell to nearest wall. Then the omega-equation uses the 1/sqr(y).
# In OpenFoam 12 wallDist is declared as shown below →
#
#                                         wallDist
#                                         {
#                                             method meshWave;
#                                         }
# meshWave - Imagine you drop a wane from all wall faces. It spreads through mesh. Distance increases as wave travels. That is how wall distance is computed. It is like flood-fill algorithm.

# %% [markdown]
# ## Issue 4: div(phi,omega) Missing
#
# ## Error:
# div(phi,omega) not defined in fvSchemes
#
# ### Root Cause:
# Convection term for omega transport requires explicit discretization scheme.
#
# ## Physics Insight:
# Imagine you have muddy water flowing in a river. The mud (dirt) is being carried by the water.
# Here water symbolizes velocity and mud as omega.
# Now How does the mud move with the weater? By transport.
#
# Omega-equation contains the convection term →
# $$
# \frac{D\omega}{Dt} =
# \frac{\partial \omega}{\partial t}
# + \vec{U} \cdot \nabla \omega
# $$
#
# In equations, the second term, $$\vec{U} \cdot \nabla \omega$$ in finite volume form looks like $$\nabla(\phi \omega)$$
# In Openfoam language, it is div(phi,omega). It means how omega is transported by the flow.
#
# Here phi = mass flux thrugh faces,
#      omega = turbulence variable
#
# So if this term is descretized poorly, then turbulence oscillates, solution becomes unstable, courant number explodes.
#
#
# Why openfoam needs it expicitly?
# In fvSchemes, you would see,
#
#                                 divSchemes
#                                 {
#                                     div(phi,U)      Guass linearUpwind grad(U);
#                                     div(phi,k)      Gauss upwind;
#                                     div(phi,omega)  Gauss upwind;
#                                 }
#
# Openfoam does not assume default schemes. Because discretization chice chnages physics behaviour.
# For Upwind               → stable but diffusive
#     Central Differencing → accurate but unstable
#     Limited schemes      → balanced
# Therefore, openfoam forces you to explicitly declare scheme for each transported variable.

# %%
## Issue 6: Forces Block Not Working

## Issue 6: Forces Block Not Working

### Error:
Cannot find configuration file forces.

# %% [markdown]
# # After all these issues, I managed to run the simulation.
# #I ran it till 5 Secs. Earlier I had ran it ntil 0.1 secs only.
# # when running till (0–0.1 s):
# - Flow is artificially clean
# - No developed wake
# - Recirculation bubble not fully formed
# - Forces are not reliable
#
# # Between 0.1–5 s:
#
# - Flow separates at slant edge
# - Recirculation region forms behind Ahmed body
# - Vortex shedding begins
# - Pressure distribution stabilizes
# - Drag force begins oscillating around a mean value
#
# We can think in this way →
# At 0.1 s → you are solving a startup problem
# At 5 s → you are solving a developed wake problem
#
# The imualtion ran successfully for 5 mins. I observed:
# →the drag force converging near ~31-32N
# →Force oscillations reduced compared to early time.
# This indicates that the wake has reached a quasi-steady condition.
#
# Therefore a stable drag value is obtained. A stable drag value indicates:
# - Flow field reached statistical stability
# - Recirculation bubble no longer growing
# - No numerical divergence
# - Courant number under control.
#
# Why 5 seconds was important?
#
# Domain length = 5m
#
# Velocity = 25 m/s
#
# Convective time scale, t = $$\frac{L}{U}$$ = $$\frac{5}{25}$$ = 0.2secs
# I ran 5ses → that is 25 convective time scales. That is more than sufficient for wake developemnt.
#
# What still needs work?
#
# Although forces stabilized:
#
# • Cd ≈ 0.75 (too high compared to literature ~0.3)
# • Mesh extremely coarse (~40k tets)
# • No grid independence study performed
# • No boundary layer refinement
#
# Conclusion:
# Solver stable, but solution not yet validated.
